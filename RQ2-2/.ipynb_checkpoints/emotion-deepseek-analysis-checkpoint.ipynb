# %% [markdown]
# ## 讀取資料

# %%
import pandas as pd
from scipy.stats import mannwhitneyu, chi2_contingency
from statsmodels.stats.proportion import proportions_ztest

df = pd.read_csv("emotion_deepseek.csv")

# 確認欄位
print("Columns:", df.columns)
# Out:
# Columns: Index(['emotion_id', 'article_id', 'entity', 'entity_type', 'asian_status',
#        'emotion', 'emotion_path', 'emotion_reason'],
#       dtype='object')

# %%
df.head()
# Out:
#   emotion_id article_id         entity    entity_type        asian_status  \
# 0  emotion_1  Article_1   Julie Morita  professionals               Asian
# 1  emotion_2  Article_1   Julie Morita  professionals               Asian
# 2  emotion_3  Article_1    Gilbert Gee  professionals               Asian
# 3  emotion_4  Article_1     Thu Nguyen  professionals               Asian
# 4  emotion_5  Article_1  Shanise Criss  professionals  Cannot be inferred
#
#               emotion  emotion_path  \
# 0  Cannot be inferred           NaN
# 1  Cannot be inferred           NaN
# 2  Cannot be inferred           NaN
# 3  Cannot be inferred           NaN
# 4  Cannot be inferred           NaN
#
#                                       emotion_reason
# 0  Julie Morita, M.D., is executive vice presiden...
# 1  She was formerly a medical director, the chief...
# 2  The research team was comprised of a group of ...
# 3  The research team was comprised of a group of ...
# 4  The research team was comprised of a group of ...

# %% [markdown]
# ## Preprocess - Mainstream v.s Non-Mainstream

# %%
# 1) 讀取 Excel (id 對應 media_type)
excel_df = pd.read_excel('articles_584.xlsx', usecols=['id', 'media_type'])
id_to_media = dict(zip(excel_df['id'], excel_df['media_type']))

# 2) 從 article_id 提取數字部分，轉成整數
df['article_num'] = df['article_id'].str.extract(r'(\d+)').astype(int)

# 3) 用 mapping 加上 mainstream / nonmainstream 欄位
df['media_group'] = df['article_num'].map(id_to_media).fillna('unknown')
df['mainstream'] = df['media_group'].map({'mainstream': "1", 'nonmainstream': "0"})

# 4) 存回新檔
df.to_csv('emotion_deepseek_with_media.csv', index=False, encoding='utf-8-sig')

print("✅ Done! 已新增欄位 'media_group' (mainstream / nonmainstream)")
# Out:
# ✅ Done! 已新增欄位 'media_group' (mainstream / nonmainstream)

# %%
df.head()
# Out:
#   emotion_id article_id         entity    entity_type        asian_status  \
# 0  emotion_1  Article_1   Julie Morita  professionals               Asian
# 1  emotion_2  Article_1   Julie Morita  professionals               Asian
# 2  emotion_3  Article_1    Gilbert Gee  professionals               Asian
# 3  emotion_4  Article_1     Thu Nguyen  professionals               Asian
# 4  emotion_5  Article_1  Shanise Criss  professionals  Cannot be inferred
#
#               emotion  emotion_path  \
# 0  Cannot be inferred           NaN
# 1  Cannot be inferred           NaN
# 2  Cannot be inferred           NaN
# 3  Cannot be inferred           NaN
# 4  Cannot be inferred           NaN
#
#                                       emotion_reason  article_num media_group  \
# 0  Julie Morita, M.D., is executive vice presiden...            1  mainstream
# 1  She was formerly a medical director, the chief...            1  mainstream
# 2  The research team was comprised of a group of ...            1  mainstream
# 3  The research team was comprised of a group of ...            1  mainstream
# 4  The research team was comprised of a group of ...            1  mainstream
#
#   mainstream
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %% [markdown]
# ## 定義 source type

# %%
source_type_cols = [
    'politicians', 'professionals', 'celebrities', 'perpetrators', 'victims',
    'other_individuals', 'law_enforcement_agencies', 'government_bodies',
    'ngo_or_advocacy_groups', 'business_entities', 'community_groups'
]

individual_cols = [
    'politicians', 'professionals', 'celebrities',
    'perpetrators', 'victims', 'other_individuals'
]

organization_cols = [
    'law_enforcement_agencies', 'government_bodies',
    'ngo_or_advocacy_group', 'business_entities', 'community_groups'
]

# %% [markdown]
# ## Victim 情緒分析

# %% [markdown]
# ### 次數／比例分析

# %%
# 篩選條件
target_emotions = ['Anger', 'Sadness', 'Love', 'Fear', 'Joy']
filtered = df[
    (df['entity_type'] == 'victims') &
    (df['emotion'].isin(target_emotions))
]

# 統計各情緒的次數
emotion_counts = (
    filtered.groupby(['media_group', 'emotion'])
    .size()
    .reset_index(name='count')
)

# 計算比例
# 在同一個媒體（ mainstream 或 nonmainstream ）內，各個情緒的出現次數相對於該媒體的總情緒次數的比例
emotion_counts['percentage'] = (
    emotion_counts.groupby('media_group')['count']
    .transform(lambda x: round(100 * x / x.sum(), 2))
)

emotion_counts
# Out:
#       media_group  emotion  count  percentage
# 0      mainstream    Anger     38       13.19
# 1      mainstream     Fear    145       50.35
# 2      mainstream      Joy     11        3.82
# 3      mainstream     Love      3        1.04
# 4      mainstream  Sadness     91       31.60
# 5  non-mainstream    Anger     66       10.28
# 6  non-mainstream     Fear    369       57.48
# 7  non-mainstream      Joy     21        3.27
# 8  non-mainstream     Love      7        1.09
# 9  non-mainstream  Sadness    179       27.88

# %%
import matplotlib.pyplot as plt
import numpy as np

# 確保情緒順序固定（避免亂序）
emotions = ['Anger', 'Sadness', 'Love', 'Fear', 'Joy']
media_groups = emotion_counts['media_group'].unique()

# 建立 x 軸位置
x = np.arange(len(emotions))
bar_width = 0.35  # 每個長條寬度

plt.figure(figsize=(8, 5))

for i, group in enumerate(media_groups):
    subset = emotion_counts[emotion_counts['media_group'] == group].set_index('emotion').reindex(emotions).fillna(0)
    plt.bar(x + i * bar_width, subset['percentage'], width=bar_width, label=group, alpha=0.8)

# 美化圖表
plt.title("Emotion Distribution for Victims in Mainstream vs Non-mainstream Media", fontsize=12)
plt.xlabel("Emotion", fontsize=11)
plt.ylabel("Percentage (%)", fontsize=11)
plt.xticks(x + bar_width / 2, emotions)
plt.legend(title="Media Group")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 文章數 vs. 情緒出現數

# %%
# 每個媒體群組的文章數（unique article_id）
article_counts = filtered.groupby('media_group')['article_id'].nunique().reset_index(name='num_articles')

# 每個媒體群組的情緒出現總數
emotion_total = filtered.groupby('media_group').size().reset_index(name='num_emotions')

# 合併比較
summary = pd.merge(article_counts, emotion_total, on='media_group')
summary['emotions_per_article'] = round(summary['num_emotions'] / summary['num_articles'], 2)
summary
# Out:
#       media_group  num_articles  num_emotions  emotions_per_article
# 0      mainstream            66           288                  4.36
# 1  non-mainstream           201           642                  3.19

# %% [markdown]
# ### 每篇文章出現情緒的覆蓋率

# %%
article_level = (
    filtered.groupby(['media_group', 'article_id', 'emotion'])
    .size()
    .reset_index()
)

# 每個媒體群組中，每種情緒出現的文章篇數
article_emotion_counts = (
    article_level.groupby(['media_group', 'emotion'])
    .size()
    .reset_index(name='article_count')
)

# 該媒體總文章數
total_articles = (
    filtered.groupby('media_group')['article_id']
    .nunique()
    .reset_index(name='total_articles')
)

# 合併計算比例
article_emotion_counts = article_emotion_counts.merge(total_articles, on='media_group')
article_emotion_counts['article_ratio'] = round(
    100 * article_emotion_counts['article_count'] / article_emotion_counts['total_articles'], 2
)

article_emotion_counts
# Out:
#       media_group  emotion  article_count  total_articles  article_ratio
# 0      mainstream    Anger             25              66          37.88
# 1      mainstream     Fear             56              66          84.85
# 2      mainstream      Joy              7              66          10.61
# 3      mainstream     Love              2              66           3.03
# 4      mainstream  Sadness             36              66          54.55
# 5  non-mainstream    Anger             46             201          22.89
# 6  non-mainstream     Fear            170             201          84.58
# 7  non-mainstream      Joy              9             201           4.48
# 8  non-mainstream     Love              4             201           1.99
# 9  non-mainstream  Sadness             93             201          46.27

# %%
import matplotlib.pyplot as plt
import numpy as np

# 固定情緒順序，讓兩組對齊
media_groups = article_emotion_counts['media_group'].unique()

# x 軸位置
x = np.arange(len(emotions))
bar_width = 0.35

plt.figure(figsize=(8, 5))

for i, group in enumerate(media_groups):
    subset = (
        article_emotion_counts[article_emotion_counts['media_group'] == group]
        .set_index('emotion')
        .reindex(emotions)
        .fillna(0)
    )
    plt.bar(x + i * bar_width, subset['article_ratio'], width=bar_width, label=group, alpha=0.8)

# 加上數值標籤
for i, group in enumerate(media_groups):
    subset = (
        article_emotion_counts[article_emotion_counts['media_group'] == group]
        .set_index('emotion')
        .reindex(emotions)
        .fillna(0)
    )
    for j, val in enumerate(subset['article_ratio']):
        plt.text(x[j] + i * bar_width, val + 0.5, f"{val:.1f}", ha='center', va='bottom', fontsize=9)

# 美化圖表
plt.title("Emotion Presence by Media Type (Article-level Analysis)", fontsize=12)
plt.xlabel("Emotion", fontsize=11)
plt.ylabel("Percentage of Articles (%)", fontsize=11)
plt.xticks(x + bar_width / 2, emotions)
plt.legend(title="Media Group")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 比例檢定（統計顯著性）

# %% [markdown]
# #### 文章出現比例

# %%
from statsmodels.stats.proportion import proportions_ztest
import pandas as pd

# 假設你前面已經建立好 article_emotion_counts
# 欄位包含：media_group, emotion, article_count, total_articles

# 建立結果列表
results = []

# 取得所有情緒
emotions = article_emotion_counts['emotion'].unique()

for emo in emotions:
    # 取出該情緒在兩種媒體群組的資料
    sub = article_emotion_counts[article_emotion_counts['emotion'] == emo]

    # 確保順序為 [mainstream, nonmainstream]
    sub = sub.set_index('media_group').reindex(['mainstream', 'non-mainstream'])
    
    count = sub['article_count'].values
    nobs = sub['total_articles'].values

    # 若資料不完整則跳過
    if len(count) < 2 or count[0] == 0 and count[1] == 0:
        continue

    # 執行比例 z 檢定
    z, p = proportions_ztest(count, nobs)

    results.append({
        'emotion': emo,
        'mainstream_ratio': round(100 * count[0] / nobs[0], 2),
        'nonmainstream_ratio': round(100 * count[1] / nobs[1], 2),
        'z_value': round(z, 3),
        'p_value': round(p, 4),
        'significant': 'Yes' if p < 0.05 else 'No'
    })

# 轉成 DataFrame
ztest_results = pd.DataFrame(results)
ztest_results
# Out:
#    emotion  mainstream_ratio  nonmainstream_ratio  z_value  p_value  \
# 0    Anger             37.88                22.89    2.392   0.0168
# 1     Fear             84.85                84.58    0.053   0.9577
# 2      Joy             10.61                 4.48    1.820   0.0688
# 3     Love              3.03                 1.99    0.495   0.6208
# 4  Sadness             54.55                46.27    1.167   0.2430
#
#   significant
# 0         Yes
# 1          No
# 2          No
# 3          No
# 4          No

# %% [markdown]
# #### 出現總數比例

# %%
from statsmodels.stats.proportion import proportions_ztest
import pandas as pd

# 假設 emotion_counts 已經有以下欄位：
# ['media_group', 'emotion', 'count']

results = []

# 取得所有情緒種類
emotions = emotion_counts['emotion'].unique()

for emo in emotions:
    sub = emotion_counts[emotion_counts['emotion'] == emo].set_index('media_group')
    sub = sub.reindex(['mainstream', 'non-mainstream']).fillna(0)

    # 該情緒在不同媒體的出現次數
    count = sub['count'].values

    # 各媒體的總出現次數（母體數 = 該媒體內所有情緒的總次數）
    total = emotion_counts.groupby('media_group')['count'].sum().reindex(['mainstream', 'non-mainstream']).values

    # 若資料不完整則跳過
    if len(count) < 2 or total.sum() == 0:
        continue

    # 比例 z 檢定
    z, p = proportions_ztest(count, total)

    results.append({
        'emotion': emo,
        'mainstream_ratio': round(100 * count[0] / total[0], 2),
        'nonmainstream_ratio': round(100 * count[1] / total[1], 2),
        'z_value': round(z, 3),
        'p_value': round(p, 4),
        'significant': 'Yes' if p < 0.05 else 'No'
    })

# 結果整理
ztest_counts = pd.DataFrame(results)
ztest_counts
# Out:
#    emotion  mainstream_ratio  nonmainstream_ratio  z_value  p_value  \
# 0    Anger             13.19                10.28    1.304   0.1923
# 1     Fear             50.35                57.48   -2.022   0.0432
# 2      Joy              3.82                 3.27    0.424   0.6714
# 3     Love              1.04                 1.09   -0.067   0.9469
# 4  Sadness             31.60                27.88    1.154   0.2484
#
#   significant
# 0          No
# 1         Yes
# 2          No
# 3          No
# 4          No

# %% [markdown]
# ## Individuals 情緒分析

# %% [markdown]
# ### 次數／比例分析

# %%
# 篩選條件
filtered = df[
    (df['entity_type'].isin(individual_cols)) &
    (df['emotion'].isin(target_emotions))
]

# 統計各情緒的次數
emotion_counts = (
    filtered.groupby(['media_group', 'emotion'])
    .size()
    .reset_index(name='count')
)

# 計算比例
# 在同一個媒體（ mainstream 或 nonmainstream ）內，各個情緒的出現次數相對於該媒體的總情緒次數的比例
emotion_counts['percentage'] = (
    emotion_counts.groupby('media_group')['count']
    .transform(lambda x: round(100 * x / x.sum(), 2))
)

emotion_counts
# Out:
#       media_group  emotion  count  percentage
# 0      mainstream    Anger    442       28.10
# 1      mainstream     Fear    524       33.31
# 2      mainstream      Joy     85        5.40
# 3      mainstream     Love     33        2.10
# 4      mainstream  Sadness    489       31.09
# 5  non-mainstream    Anger    851       30.13
# 6  non-mainstream     Fear   1025       36.30
# 7  non-mainstream      Joy    157        5.56
# 8  non-mainstream     Love     37        1.31
# 9  non-mainstream  Sadness    754       26.70

# %%
import matplotlib.pyplot as plt
import numpy as np

# 確保情緒順序固定（避免亂序）
media_groups = emotion_counts['media_group'].unique()

# 建立 x 軸位置
x = np.arange(len(emotions))
bar_width = 0.35  # 每個長條寬度

plt.figure(figsize=(8, 5))

for i, group in enumerate(media_groups):
    subset = emotion_counts[emotion_counts['media_group'] == group].set_index('emotion').reindex(emotions).fillna(0)
    plt.bar(x + i * bar_width, subset['percentage'], width=bar_width, label=group, alpha=0.8)

# 美化圖表
plt.title("Emotion Distribution for Victims in Mainstream vs Non-mainstream Media", fontsize=12)
plt.xlabel("Emotion", fontsize=11)
plt.ylabel("Percentage (%)", fontsize=11)
plt.xticks(x + bar_width / 2, emotions)
plt.legend(title="Media Group")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 文章數 vs. 情緒出現數

# %%
# 每個媒體群組的文章數（unique article_id）
article_counts = filtered.groupby('media_group')['article_id'].nunique().reset_index(name='num_articles')

# 每個媒體群組的情緒出現總數
emotion_total = filtered.groupby('media_group').size().reset_index(name='num_emotions')

# 合併比較
summary = pd.merge(article_counts, emotion_total, on='media_group')
summary['emotions_per_article'] = round(summary['num_emotions'] / summary['num_articles'], 2)
summary
# Out:
#       media_group  num_articles  num_emotions  emotions_per_article
# 0      mainstream           150          1573                 10.49
# 1  non-mainstream           398          2824                  7.10

# %% [markdown]
# ### 每篇文章出現情緒的覆蓋率

# %%
article_level = (
    filtered.groupby(['media_group', 'article_id', 'emotion'])
    .size()
    .reset_index()
)

# 每個媒體群組中，每種情緒出現的文章篇數
article_emotion_counts = (
    article_level.groupby(['media_group', 'emotion'])
    .size()
    .reset_index(name='article_count')
)

# 該媒體總文章數
total_articles = (
    filtered.groupby('media_group')['article_id']
    .nunique()
    .reset_index(name='total_articles')
)

# 合併計算比例
article_emotion_counts = article_emotion_counts.merge(total_articles, on='media_group')
article_emotion_counts['article_ratio'] = round(
    100 * article_emotion_counts['article_count'] / article_emotion_counts['total_articles'], 2
)

article_emotion_counts
# Out:
#       media_group  emotion  article_count  total_articles  article_ratio
# 0      mainstream    Anger            134             150          89.33
# 1      mainstream     Fear            130             150          86.67
# 2      mainstream      Joy             48             150          32.00
# 3      mainstream     Love             15             150          10.00
# 4      mainstream  Sadness            117             150          78.00
# 5  non-mainstream    Anger            316             398          79.40
# 6  non-mainstream     Fear            322             398          80.90
# 7  non-mainstream      Joy             84             398          21.11
# 8  non-mainstream     Love             27             398           6.78
# 9  non-mainstream  Sadness            282             398          70.85

# %%
import matplotlib.pyplot as plt
import numpy as np

# 固定情緒順序，讓兩組對齊
media_groups = article_emotion_counts['media_group'].unique()

# x 軸位置
x = np.arange(len(emotions))
bar_width = 0.35

plt.figure(figsize=(8, 5))

for i, group in enumerate(media_groups):
    subset = (
        article_emotion_counts[article_emotion_counts['media_group'] == group]
        .set_index('emotion')
        .reindex(emotions)
        .fillna(0)
    )
    plt.bar(x + i * bar_width, subset['article_ratio'], width=bar_width, label=group, alpha=0.8)

# 加上數值標籤
for i, group in enumerate(media_groups):
    subset = (
        article_emotion_counts[article_emotion_counts['media_group'] == group]
        .set_index('emotion')
        .reindex(emotions)
        .fillna(0)
    )
    for j, val in enumerate(subset['article_ratio']):
        plt.text(x[j] + i * bar_width, val + 0.5, f"{val:.1f}", ha='center', va='bottom', fontsize=9)

# 美化圖表
plt.title("Emotion Presence by Media Type (Article-level Analysis)", fontsize=12)
plt.xlabel("Emotion", fontsize=11)
plt.ylabel("Percentage of Articles (%)", fontsize=11)
plt.xticks(x + bar_width / 2, emotions)
plt.legend(title="Media Group")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 比例檢定（統計顯著性）

# %% [markdown]
# #### 文章出現比例

# %%
from statsmodels.stats.proportion import proportions_ztest
import pandas as pd

# 建立結果列表
results = []

# 取得所有情緒
emotions = article_emotion_counts['emotion'].unique()

for emo in emotions:
    # 取出該情緒在兩種媒體群組的資料
    sub = article_emotion_counts[article_emotion_counts['emotion'] == emo]

    # 確保順序為 [mainstream, nonmainstream]
    sub = sub.set_index('media_group').reindex(['mainstream', 'non-mainstream'])
    
    count = sub['article_count'].values
    nobs = sub['total_articles'].values

    # 若資料不完整則跳過
    if len(count) < 2 or count[0] == 0 and count[1] == 0:
        continue

    # 執行比例 z 檢定
    z, p = proportions_ztest(count, nobs)

    results.append({
        'emotion': emo,
        'mainstream_ratio': round(100 * count[0] / nobs[0], 2),
        'nonmainstream_ratio': round(100 * count[1] / nobs[1], 2),
        'z_value': round(z, 3),
        'p_value': round(p, 4),
        'significant': 'Yes' if p < 0.05 else 'No'
    })

# 轉成 DataFrame
ztest_results = pd.DataFrame(results)
ztest_results
# Out:
#    emotion  mainstream_ratio  nonmainstream_ratio  z_value  p_value  \
# 0    Anger             89.33                79.40    2.706   0.0068
# 1     Fear             86.67                80.90    1.582   0.1136
# 2      Joy             32.00                21.11    2.659   0.0078
# 3     Love             10.00                 6.78    1.262   0.2070
# 4  Sadness             78.00                70.85    1.676   0.0937
#
#   significant
# 0         Yes
# 1          No
# 2         Yes
# 3          No
# 4          No

# %% [markdown]
# #### 出現總數比例

# %%
from statsmodels.stats.proportion import proportions_ztest
import pandas as pd

# 假設 emotion_counts 已經有以下欄位：
# ['media_group', 'emotion', 'count']

results = []

# 取得所有情緒種類
emotions = emotion_counts['emotion'].unique()

for emo in emotions:
    sub = emotion_counts[emotion_counts['emotion'] == emo].set_index('media_group')
    sub = sub.reindex(['mainstream', 'non-mainstream']).fillna(0)

    # 該情緒在不同媒體的出現次數
    count = sub['count'].values

    # 各媒體的總出現次數（母體數 = 該媒體內所有情緒的總次數）
    total = emotion_counts.groupby('media_group')['count'].sum().reindex(['mainstream', 'non-mainstream']).values

    # 若資料不完整則跳過
    if len(count) < 2 or total.sum() == 0:
        continue

    # 比例 z 檢定
    z, p = proportions_ztest(count, total)

    results.append({
        'emotion': emo,
        'mainstream_ratio': round(100 * count[0] / total[0], 2),
        'nonmainstream_ratio': round(100 * count[1] / total[1], 2),
        'z_value': round(z, 3),
        'p_value': round(p, 4),
        'significant': 'Yes' if p < 0.05 else 'No'
    })

# 結果整理
ztest_counts = pd.DataFrame(results)
ztest_counts
# Out:
#    emotion  mainstream_ratio  nonmainstream_ratio  z_value  p_value  \
# 0    Anger             28.10                30.13   -1.420   0.1556
# 1     Fear             33.31                36.30   -1.985   0.0471
# 2      Joy              5.40                 5.56   -0.217   0.8281
# 3     Love              2.10                 1.31    2.000   0.0455
# 4  Sadness             31.09                26.70    3.097   0.0020
#
#   significant
# 0          No
# 1         Yes
# 2          No
# 3         Yes
# 4         Yes

# %% [markdown]
# ## Organizations 情緒分析

# %% [markdown]
# ### 次數／比例分析

# %%
# 篩選條件
filtered = df[
    (df['entity_type'].isin(organization_cols)) &
    (df['emotion'].isin(target_emotions))
]

# 統計各情緒的次數
emotion_counts = (
    filtered.groupby(['media_group', 'emotion'])
    .size()
    .reset_index(name='count')
)

# 計算比例
# 在同一個媒體（ mainstream 或 nonmainstream ）內，各個情緒的出現次數相對於該媒體的總情緒次數的比例
emotion_counts['percentage'] = (
    emotion_counts.groupby('media_group')['count']
    .transform(lambda x: round(100 * x / x.sum(), 2))
)

emotion_counts
# Out:
#       media_group  emotion  count  percentage
# 0      mainstream    Anger     13       34.21
# 1      mainstream     Fear     16       42.11
# 2      mainstream     Love      1        2.63
# 3      mainstream  Sadness      8       21.05
# 4  non-mainstream    Anger     46       25.70
# 5  non-mainstream     Fear     81       45.25
# 6  non-mainstream      Joy     10        5.59
# 7  non-mainstream     Love      5        2.79
# 8  non-mainstream  Sadness     37       20.67

# %%
import matplotlib.pyplot as plt
import numpy as np

# 確保情緒順序固定（避免亂序）
media_groups = emotion_counts['media_group'].unique()

# 建立 x 軸位置
x = np.arange(len(emotions))
bar_width = 0.35  # 每個長條寬度

plt.figure(figsize=(8, 5))

for i, group in enumerate(media_groups):
    subset = emotion_counts[emotion_counts['media_group'] == group].set_index('emotion').reindex(emotions).fillna(0)
    plt.bar(x + i * bar_width, subset['percentage'], width=bar_width, label=group, alpha=0.8)

# 美化圖表
plt.title("Emotion Distribution for Victims in Mainstream vs Non-mainstream Media", fontsize=12)
plt.xlabel("Emotion", fontsize=11)
plt.ylabel("Percentage (%)", fontsize=11)
plt.xticks(x + bar_width / 2, emotions)
plt.legend(title="Media Group")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 文章數 vs. 情緒出現數

# %%
# 每個媒體群組的文章數（unique article_id）
article_counts = filtered.groupby('media_group')['article_id'].nunique().reset_index(name='num_articles')

# 每個媒體群組的情緒出現總數
emotion_total = filtered.groupby('media_group').size().reset_index(name='num_emotions')

# 合併比較
summary = pd.merge(article_counts, emotion_total, on='media_group')
summary['emotions_per_article'] = round(summary['num_emotions'] / summary['num_articles'], 2)
summary
# Out:
#       media_group  num_articles  num_emotions  emotions_per_article
# 0      mainstream            27            38                  1.41
# 1  non-mainstream            86           179                  2.08

# %% [markdown]
# ### 每篇文章出現情緒的覆蓋率

# %%
article_level = (
    filtered.groupby(['media_group', 'article_id', 'emotion'])
    .size()
    .reset_index()
)

# 每個媒體群組中，每種情緒出現的文章篇數
article_emotion_counts = (
    article_level.groupby(['media_group', 'emotion'])
    .size()
    .reset_index(name='article_count')
)

# 該媒體總文章數
total_articles = (
    filtered.groupby('media_group')['article_id']
    .nunique()
    .reset_index(name='total_articles')
)

# 合併計算比例
article_emotion_counts = article_emotion_counts.merge(total_articles, on='media_group')
article_emotion_counts['article_ratio'] = round(
    100 * article_emotion_counts['article_count'] / article_emotion_counts['total_articles'], 2
)

article_emotion_counts
# Out:
#       media_group  emotion  article_count  total_articles  article_ratio
# 0      mainstream    Anger             11              27          40.74
# 1      mainstream     Fear             12              27          44.44
# 2      mainstream     Love              1              27           3.70
# 3      mainstream  Sadness              8              27          29.63
# 4  non-mainstream    Anger             36              86          41.86
# 5  non-mainstream     Fear             49              86          56.98
# 6  non-mainstream      Joy              8              86           9.30
# 7  non-mainstream     Love              3              86           3.49
# 8  non-mainstream  Sadness             20              86          23.26

# %%
import matplotlib.pyplot as plt
import numpy as np

# 固定情緒順序，讓兩組對齊
media_groups = article_emotion_counts['media_group'].unique()

# x 軸位置
x = np.arange(len(emotions))
bar_width = 0.35

plt.figure(figsize=(8, 5))

for i, group in enumerate(media_groups):
    subset = (
        article_emotion_counts[article_emotion_counts['media_group'] == group]
        .set_index('emotion')
        .reindex(emotions)
        .fillna(0)
    )
    plt.bar(x + i * bar_width, subset['article_ratio'], width=bar_width, label=group, alpha=0.8)

# 加上數值標籤
for i, group in enumerate(media_groups):
    subset = (
        article_emotion_counts[article_emotion_counts['media_group'] == group]
        .set_index('emotion')
        .reindex(emotions)
        .fillna(0)
    )
    for j, val in enumerate(subset['article_ratio']):
        plt.text(x[j] + i * bar_width, val + 0.5, f"{val:.1f}", ha='center', va='bottom', fontsize=9)

# 美化圖表
plt.title("Emotion Presence by Media Type (Article-level Analysis)", fontsize=12)
plt.xlabel("Emotion", fontsize=11)
plt.ylabel("Percentage of Articles (%)", fontsize=11)
plt.xticks(x + bar_width / 2, emotions)
plt.legend(title="Media Group")
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 比例檢定（統計顯著性）

# %% [markdown]
# #### 文章出現比例

# %%
from statsmodels.stats.proportion import proportions_ztest
import pandas as pd

# 建立結果列表
results = []

# 取得所有情緒
emotions = article_emotion_counts['emotion'].unique()

for emo in emotions:
    # 取出該情緒在兩種媒體群組的資料
    sub = article_emotion_counts[article_emotion_counts['emotion'] == emo]

    # 確保順序為 [mainstream, nonmainstream]
    sub = sub.set_index('media_group').reindex(['mainstream', 'non-mainstream'])
    
    count = sub['article_count'].values
    nobs = sub['total_articles'].values

    # 若資料不完整則跳過
    if len(count) < 2 or count[0] == 0 and count[1] == 0:
        continue

    # 執行比例 z 檢定
    z, p = proportions_ztest(count, nobs)

    results.append({
        'emotion': emo,
        'mainstream_ratio': round(100 * count[0] / nobs[0], 2),
        'nonmainstream_ratio': round(100 * count[1] / nobs[1], 2),
        'z_value': round(z, 3),
        'p_value': round(p, 4),
        'significant': 'Yes' if p < 0.05 else 'No'
    })

# 轉成 DataFrame
ztest_results = pd.DataFrame(results)
ztest_results
# Out:
#    emotion  mainstream_ratio  nonmainstream_ratio  z_value  p_value  \
# 0    Anger             40.74                41.86   -0.103   0.9180
# 1     Fear             44.44                56.98   -1.140   0.2544
# 2     Love              3.70                 3.49    0.053   0.9579
# 3  Sadness             29.63                23.26    0.669   0.5033
# 4      Joy               NaN                 9.30      NaN      NaN
#
#   significant
# 0          No
# 1          No
# 2          No
# 3          No
# 4          No

# %% [markdown]
# #### 出現總數比例

# %%
from statsmodels.stats.proportion import proportions_ztest
import pandas as pd

results = []

# 取得所有情緒種類
emotions = emotion_counts['emotion'].unique()

for emo in emotions:
    sub = emotion_counts[emotion_counts['emotion'] == emo].set_index('media_group')
    sub = sub.reindex(['mainstream', 'non-mainstream']).fillna(0)

    # 該情緒在不同媒體的出現次數
    count = sub['count'].values

    # 各媒體的總出現次數（母體數 = 該媒體內所有情緒的總次數）
    total = emotion_counts.groupby('media_group')['count'].sum().reindex(['mainstream', 'non-mainstream']).values

    # 若資料不完整則跳過
    if len(count) < 2 or total.sum() == 0:
        continue

    # 比例 z 檢定
    z, p = proportions_ztest(count, total)

    results.append({
        'emotion': emo,
        'mainstream_ratio': round(100 * count[0] / total[0], 2),
        'nonmainstream_ratio': round(100 * count[1] / total[1], 2),
        'z_value': round(z, 3),
        'p_value': round(p, 4),
        'significant': 'Yes' if p < 0.05 else 'No'
    })

# 結果整理
ztest_counts = pd.DataFrame(results)
ztest_counts
# Out:
#    emotion  mainstream_ratio  nonmainstream_ratio  z_value  p_value  \
# 0    Anger             13.19                10.28    1.304   0.1923
# 1     Fear             50.35                57.48   -2.022   0.0432
# 2      Joy              3.82                 3.27    0.424   0.6714
# 3     Love              1.04                 1.09   -0.067   0.9469
# 4  Sadness             31.60                27.88    1.154   0.2484
#
#   significant
# 0          No
# 1         Yes
# 2          No
# 3          No
# 4          No

# %% [markdown]
# ## 綜合分析

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# === 篩選資料 ===
filtered = df[
    (df['entity_type'].isin(source_type_cols)) &
    (df['emotion'].isin(target_emotions))
]

# === 統計各媒體群組、各 entity_type、各情緒的出現次數 ===
emotion_counts = (
    filtered.groupby(['media_group', 'entity_type', 'emotion'])
    .size()
    .reset_index(name='count')
)

# === 計算比例（同一媒體 + 同一 entity_type 內的情緒構成百分比）===
emotion_counts['percentage'] = (
    emotion_counts.groupby(['media_group', 'entity_type'])['count']
    .transform(lambda x: round(100 * x / x.sum(), 2))
)
emotion_counts
# Out:
#        media_group        entity_type  emotion  count  percentage
# 0       mainstream  business_entities    Anger      5       45.45
# 1       mainstream  business_entities     Fear      3       27.27
# 2       mainstream  business_entities     Love      1        9.09
# 3       mainstream  business_entities  Sadness      2       18.18
# 4       mainstream        celebrities    Anger     22       44.00
# ..             ...                ...      ...    ...         ...
# 86  non-mainstream            victims    Anger     66       10.28
# 87  non-mainstream            victims     Fear    369       57.48
# 88  non-mainstream            victims      Joy     21        3.27
# 89  non-mainstream            victims     Love      7        1.09
# 90  non-mainstream            victims  Sadness    179       27.88
#
# [91 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# === 設定 ===
emotions = target_emotions
media_groups = ['mainstream', 'non-mainstream']
colors = plt.cm.tab10.colors[:len(emotions)]

# === 整理資料 ===
pivot_data = (
    emotion_counts
    .pivot_table(index=['entity_type', 'media_group'], columns='emotion', values='percentage', fill_value=0)
    .reindex(index=pd.MultiIndex.from_product([source_type_cols, media_groups]), fill_value=0)
)

# === 準備 X 軸 ===
x = np.arange(len(source_type_cols))
bar_width = 0.35

plt.figure(figsize=(12, 6))

# === 繪製堆疊長條 ===
for i, group in enumerate(media_groups):
    bottoms = np.zeros(len(source_type_cols))
    for k, emo in enumerate(emotions):
        y = [pivot_data.loc[(ent, group), emo] for ent in source_type_cols]
        plt.bar(
            x + i * bar_width ,
            y,
            width=bar_width,
            bottom=bottoms,
            color=colors[k],
            alpha=0.5 if group == 'non-mainstream' else 0.9,
            label=f"{emo}" if i == 0 else None
        )
        bottoms += y

# === 格式與標籤 ===
plt.xticks(x + bar_width / 2, [ent.replace('_', ' ').title() for ent in source_type_cols], rotation=30, ha='right')
plt.ylabel("Percentage (%)")
plt.title("Stacked Emotion Distribution by Entity Type — Mainstream vs Nonmainstream", fontsize=13)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.legend(title="Emotion", bbox_to_anchor=(1.02, 1), loc='upper left')

plt.tight_layout()
plt.show()
